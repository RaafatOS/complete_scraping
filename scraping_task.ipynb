# %%
import requests
import csv
import time
from bs4 import BeautifulSoup
from urllib.parse import urljoin

BASE_URL = "https://web.archive.org/web/20250708180027/https://www.myfootdr.com.au"
REGIONS_URL = BASE_URL + "/our-clinics/regions/"

# %%
def get_soup(url):
    resp = requests.get(url)
    resp.raise_for_status()
    return BeautifulSoup(resp.text, "html.parser")

# %%
def extract_clinic_info(clinic_url):
    soup = get_soup(clinic_url)
    # Name
    name_tag = soup.find("h1")
    name = name_tag.get_text(strip=True) if name_tag else ""
    # Address — guess: look for <i> or <div> with address class or “/” symbol
    address = ""
    # Many sites have <i class="fa-map-marker" …> or similar, or <div class="address">
    ad = soup.find(lambda tag: tag.name=="i" and "fa-map-marker" in tag.get("class", []))
    if ad:
        parent = ad.parent
        if parent:
            ad.decompose()  # remove the icon
            address = parent.get_text(" ", strip=True)
    else:
        # fallback: find “/” in text or some known pattern
        addr_div = soup.find("div", class_="address") or soup.find("p", class_="address")
        if addr_div:
            for span in addr_div.find_all("span"):
                span.decompose()
            address = addr_div.get_text(" ", strip=True)
    # Email
    email = ""
    em = soup.find("a", href=lambda h: h and ("mailto:" in h or "mailt" in h))
    if em:
        email = em.get_text(strip=True)
    # Phone
    phone = ""
    ph = soup.find("a",
        class_="smart-button rose-button rose-o desktoponly",
        href=lambda h: h and ("tel:" in h or "phone" in h.lower()))
    if ph:
        phone = ph.get_text(strip=True).replace("Call", "").strip()
    else:
        # fallback: find <p> or <span> with Phone
        ph2 = soup.find(string=lambda t: t and "Call" in t or "Phone" in t)
        if ph2:
            phone = ph2.strip()
    # Services — assuming there’s a list of services
    services = []
    serv_section = soup.find(lambda tag: tag.name in ["ul","div"] and "Services Available" in tag.get_text())
    if serv_section:
        for li in serv_section.find_all("li"):
            services.append(li.get_text(strip=True))
    else:
        # fallback: find paragraphs with known keywords
        for p in soup.find_all("p"):
            txt = p.get_text(strip=True)
            if any(k in txt.lower() for k in ["orthotics", "ingrown", "laser", "footcare"]):
                services.append(txt)
    services_str = "; ".join(services)
    return {
        "Name of Clinic": name,
        "Address": address,
        "Email": email,
        "Phone": phone,
        "Services": services_str,
    }

# %%
print(extract_clinic_info("https://web.archive.org/web/20250517063937/https://www.myfootdr.com.au/our-clinics/noosa/"))
# Out:
# {'Name of Clinic': 'Allsports Podiatry Noosa', 'Address': 'Unit 4, 17 Sunshine Beach Rd Noosa QLD 4567', 'Email': 'vnoosa@allsportspodiatry.com.au', 'Phone': '07 5447 3312', 'Services': "Ingrown toenails on a woman's foot, pain in the big toe closeup; Ingrown toenails, also known as onychocryptosis, are a common and painful complaint. A true ingrown toenail is when a spike or edge of nail pierces the skin at the nail edge. This is known as the sulcus and can cause inflammation and even lead to infection.There are a variety of factors that can cause ingrown toenails. The most common cause is due to improper cutting of your toenail and leaving a spike of nail in the sulcus. It can also be a result of a curved nail, known as an involuted nail, from external pressure.If you are experiencing pain, redness, and swelling around your toenail, it may be time to consider seeing one of our podiatrists. With over 30 years of combined experience in treating foot and ankle conditions, we have successfully treated many cases of ingrown toenails."}

# %%
def get_all_clinic_links(start_url):
    """
    Start from the main clinics page, visit each region,
    and return a list of clinic page URLs.
    """
    clinic_urls = []

    # Step 1: Get regions from the main page
    soup = get_soup(start_url)
    region_links = [
        a['href'] for a in soup.find_all('a', href=True)
        if "/our-clinics/" in a['href'] and "regions" in a['href']
    ]
    region_links = list(set(region_links))  # unique links

    print(f"Found {len(region_links)} regions.")

    # Step 2: Visit each region and get clinic links
    for rlink in region_links:
        region_url = urljoin(BASE_URL, rlink)
        print(f"Processing region: {region_url}")
        soup_region = get_soup(region_url)

        # Find clinic links in the region page
        clinic_anchors = [
            a for a in soup_region.find_all("a", href=True)
            if "/our-clinics/" in a['href'] and "regions" not in a['href']
        ]
        for a in clinic_anchors:
            clinic_url = urljoin(BASE_URL, a['href'])
            clinic_urls.append(clinic_url)
            print(f"  → Found clinic: {clinic_url}")

        time.sleep(1)  # polite pause per region

    print(f"Total clinics found: {len(clinic_urls)}")
    return clinic_urls

# %%
clinics = get_all_clinic_links(REGIONS_URL)
# Out:
# Found 12 regions.
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/brisbane/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/albany-creek-allsports-podiatry/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/aspley-allsports-podiatry/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/calamvale-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/camp-hill-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/forest-lake-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/hawthorne-podiatry-clinic-allsports-podiatry/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/indooroopilly-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/kangaroo-point-allsports-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/red-hill-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/the-gap-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/toowong-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/wavell-heights-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/newstead-podiatry-clinic-anytime-physio-podiatry/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/brisbane-cbd-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/mitchelton-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/brookwater-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/camp-hill-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/cleveland-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/fortitude-valley-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/gumdale-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/indooroopilly-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/ipswich-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/jindalee-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/mountgravatt-podiatry-orthotics-customfootwear/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/north-lakes-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/red-hill/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/redcliffe-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/shailer-park-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/stafford-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/toowoomba-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/wellington-point-podiatry-centre-allsports/
#   → Found clinic: https://web.archive.org/web/20250829222334/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/sunshine-coast/
#   → Found clinic: https://web.archive.org/web/20250907175225/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250907175225/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250907175225/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250907175225/https://www.myfootdr.com.au/our-clinics/noosa/
#   → Found clinic: https://web.archive.org/web/20250907175225/https://www.myfootdr.com.au/our-clinics/beerwah-podiatry-clinic/
#   → Found clinic: https://web.archive.org/web/20250907175225/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/new-south-wales/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/bathurst-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/blacktown-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/burwood-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/casula-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/cessnock-back-in-motion-podiatry/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/charlestown/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/dubbo-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/mittagong-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/moorebank-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/narellan-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/orange-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/tweed-heads-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250814052138/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/south-australia/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/aldinga-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/blackwood-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/christies-beach-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/hove-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/modbury-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/bim-podiatry-woodville/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/semaphore-podiatry-clinic/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/stirling-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/unley-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201740/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/
#   → Found clinic: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/tasmania/
#   → Found clinic: https://web.archive.org/web/20250907212100/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250907212100/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250907212100/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250907212100/https://www.myfootdr.com.au/our-clinics/devonport-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250907212100/https://www.myfootdr.com.au/our-clinics/south-hobart-ispahan-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250907212100/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/north-queensland/
#   → Found clinic: https://web.archive.org/web/20250906133640/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250906133640/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250906133640/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250906133640/https://www.myfootdr.com.au/our-clinics/cairns-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250906133640/https://www.myfootdr.com.au/our-clinics/cowboys-centre-of-excellence-nq-foot-ankle-centre/
#   → Found clinic: https://web.archive.org/web/20250906133640/https://www.myfootdr.com.au/our-clinics/my-footdr-nq-foot/
#   → Found clinic: https://web.archive.org/web/20250906133640/https://www.myfootdr.com.au/our-clinics/thuringowa-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250906133640/https://www.myfootdr.com.au/our-clinics/townsville-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250906133640/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/western-australia/
#   → Found clinic: https://web.archive.org/web/20250829201703/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201703/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201703/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201703/https://www.myfootdr.com.au/our-clinics/bim-podiatry-balcatta/
#   → Found clinic: https://web.archive.org/web/20250829201703/https://www.myfootdr.com.au/our-clinics/como-back-in-motion-podiatry/
#   → Found clinic: https://web.archive.org/web/20250829201703/https://www.myfootdr.com.au/our-clinics/currambine-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201703/https://www.myfootdr.com.au/our-clinics/warwick-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201703/https://www.myfootdr.com.au/our-clinics/wembley-downs-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201703/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/central-queensland/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/bargara-advanced-foot-care-podiatry-clinic/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/bundaberg-advanced-foot-care-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/hervey-bay-advanced-foot-care-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/monto-advanced-foot-care-podiatry-clinic/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/gladstone-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/mackay-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/rockhampton-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/yeppoon-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250707223226/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/northern-territory/
#   → Found clinic: https://web.archive.org/web/20250829201720/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201720/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201720/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201720/https://www.myfootdr.com.au/our-clinics/palmerston-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201720/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/gold-coast/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/allsports-podiatry-parkwood/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/pimpama-allsports-podiatry/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/bundall-back-in-motion-podiatry/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/burleigh-waters-back-in-motion-podiatry/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/hope-island-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/robina-physiologic-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/robina-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829222349/https://www.myfootdr.com.au/our-clinics/
# Processing region: https://web.archive.org/web/20250804040701/https://www.myfootdr.com.au/our-clinics/regions/victoria/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/back-in-motion-podiatry-bacchus-marsh/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/bayswater-back-in-motion-podiatry/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/back-in-motion-podiatry-melton/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/ballarat-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/wodonga-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/boronia-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/cranbourne-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/pakenham-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/moe-the-foot-and-ankle-clinic-podiatry-clinic/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/chadstone-the-foot-and-ankle-clinic-podiatry-clinic/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/east-bentleigh-the-foot-and-ankle-clinic-podiatry-clinic/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/sale-the-foot-and-ankle-clinic-podiatry-clinic/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/traralgon-the-foot-and-ankle-clinic-podiatry-clinic/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/wantirna-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/warragul-podiatry-centre/
#   → Found clinic: https://web.archive.org/web/20250829201729/https://www.myfootdr.com.au/our-clinics/
# Total clinics found: 145

# %%
# remove duplicates and the ones without proper URLs (ending with 'our-clinics/')
un_clinics = list(set([c for c in clinics if not c.endswith("our-clinics/")]))
print(f"Unique clinics to process: {len(un_clinics)}")
# Out:
# Unique clinics to process: 97

# %%
# clean the clinic URLs remove the part before https://wwww.myfootdr.com.au
# split and keep only the path part
test = [c.split("https://www.myfootdr.com.au")[-1] if "https://www.myfootdr.com.au" in c else c for c in un_clinics]
test = ["https://www.myfootdr.com.au"+c for c in test]
print(test)
# Out:
# ['https://www.myfootdr.com.au/our-clinics/kangaroo-point-allsports-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/charlestown/', 'https://www.myfootdr.com.au/our-clinics/aspley-allsports-podiatry/', 'https://www.myfootdr.com.au/our-clinics/bim-podiatry-balcatta/', 'https://www.myfootdr.com.au/our-clinics/back-in-motion-podiatry-bacchus-marsh/', 'https://www.myfootdr.com.au/our-clinics/christies-beach-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/townsville-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/modbury-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/moorebank-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/wembley-downs-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/sale-the-foot-and-ankle-clinic-podiatry-clinic/', 'https://www.myfootdr.com.au/our-clinics/the-gap-podiatry-centre-allsports/', 'https://www.myfootdr.com.au/our-clinics/casula-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/indooroopilly-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/bundall-back-in-motion-podiatry/', 'https://www.myfootdr.com.au/our-clinics/stirling-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/cleveland-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/burwood-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/moe-the-foot-and-ankle-clinic-podiatry-clinic/', 'https://www.myfootdr.com.au/our-clinics/indooroopilly-podiatry-centre-allsports/', 'https://www.myfootdr.com.au/our-clinics/wodonga-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/jindalee-podiatry-centre-allsports/', 'https://www.myfootdr.com.au/our-clinics/orange-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/north-lakes-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/red-hill-podiatry-centre-allsports/', 'https://www.myfootdr.com.au/our-clinics/shailer-park-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/hope-island-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/robina-physiologic-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/blacktown-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/palmerston-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/bim-podiatry-woodville/', 'https://www.myfootdr.com.au/our-clinics/back-in-motion-podiatry-melton/', 'https://www.myfootdr.com.au/our-clinics/pakenham-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/wantirna-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/hervey-bay-advanced-foot-care-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/traralgon-the-foot-and-ankle-clinic-podiatry-clinic/', 'https://www.myfootdr.com.au/our-clinics/wavell-heights-podiatry-centre-allsports/', 'https://www.myfootdr.com.au/our-clinics/aldinga-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/bargara-advanced-foot-care-podiatry-clinic/', 'https://www.myfootdr.com.au/our-clinics/como-back-in-motion-podiatry/', 'https://www.myfootdr.com.au/our-clinics/cessnock-back-in-motion-podiatry/', 'https://www.myfootdr.com.au/our-clinics/bayswater-back-in-motion-podiatry/', 'https://www.myfootdr.com.au/our-clinics/ipswich-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/dubbo-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/brookwater-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/bundaberg-advanced-foot-care-podiatry-centre/', 'https://www.myfootdr.com.au/our-clinics/cowboys-centre-of-excellence-nq-foot-ankle-centre/', 'https://www.myfootdr.com.au/our-clinics/wellington-point-podiatry-centre-allsports/', 'https://www.myfootdr.com.au/our-clinics/red-hill/', 'https://www.myfootdr.com.au/our-clinics/beerwah-podiatry-clinic/', 'https://www.myfootdr.com.au/our-clinics/monto-advanced-foot-care-podiatry-clinic/', 'https://www.myfootdr.com.au/our-clinics/east-bentleigh-the-foot-and-ankle-clinic-podiatry-clinic/', 'https://www.myfootdr.com.au/our-clinics/south-hobart-ispahan-podiat ...

# %%
def scrape_myfootdr_clinics(clinics):
    output_file = "myfootdr_clinics.csv"
    csv_fields = ["Name of Clinic", "Address", "Email", "Phone", "Services"]
    with open(output_file, mode="w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=csv_fields)
        writer.writeheader()

        for idx, clinic_url in enumerate(clinics, start=1):
            print(f"Processing clinic {idx}/{len(clinics)}: {clinic_url}")
            try:
                info = extract_clinic_info(clinic_url)
                writer.writerow(info)
            except Exception as e:
                print(f"Error processing {clinic_url}: {e}")
            time.sleep(1)  # polite pause per clinic

# %%
scrape_myfootdr_clinics(test)
# Out:
# Processing clinic 1/97: https://www.myfootdr.com.au/our-clinics/kangaroo-point-allsports-podiatry-centre/
# Processing clinic 2/97: https://www.myfootdr.com.au/our-clinics/charlestown/
# Processing clinic 3/97: https://www.myfootdr.com.au/our-clinics/aspley-allsports-podiatry/
# Processing clinic 4/97: https://www.myfootdr.com.au/our-clinics/bim-podiatry-balcatta/
# Processing clinic 5/97: https://www.myfootdr.com.au/our-clinics/back-in-motion-podiatry-bacchus-marsh/
# Processing clinic 6/97: https://www.myfootdr.com.au/our-clinics/christies-beach-podiatry-centre/
# Processing clinic 7/97: https://www.myfootdr.com.au/our-clinics/townsville-podiatry-centre/
# Processing clinic 8/97: https://www.myfootdr.com.au/our-clinics/modbury-podiatry-centre/
# Processing clinic 9/97: https://www.myfootdr.com.au/our-clinics/moorebank-podiatry-centre/
# Processing clinic 10/97: https://www.myfootdr.com.au/our-clinics/wembley-downs-podiatry-centre/
# Processing clinic 11/97: https://www.myfootdr.com.au/our-clinics/sale-the-foot-and-ankle-clinic-podiatry-clinic/
# Processing clinic 12/97: https://www.myfootdr.com.au/our-clinics/the-gap-podiatry-centre-allsports/
# Processing clinic 13/97: https://www.myfootdr.com.au/our-clinics/casula-podiatry-centre/
# Processing clinic 14/97: https://www.myfootdr.com.au/our-clinics/indooroopilly-podiatry-centre/
# Processing clinic 15/97: https://www.myfootdr.com.au/our-clinics/bundall-back-in-motion-podiatry/
# Processing clinic 16/97: https://www.myfootdr.com.au/our-clinics/stirling-podiatry-centre/
# Processing clinic 17/97: https://www.myfootdr.com.au/our-clinics/cleveland-podiatry-centre/
# Processing clinic 18/97: https://www.myfootdr.com.au/our-clinics/burwood-podiatry-centre/
# Processing clinic 19/97: https://www.myfootdr.com.au/our-clinics/moe-the-foot-and-ankle-clinic-podiatry-clinic/
# Processing clinic 20/97: https://www.myfootdr.com.au/our-clinics/indooroopilly-podiatry-centre-allsports/
# Processing clinic 21/97: https://www.myfootdr.com.au/our-clinics/wodonga-podiatry-centre/
# Processing clinic 22/97: https://www.myfootdr.com.au/our-clinics/jindalee-podiatry-centre-allsports/
# Processing clinic 23/97: https://www.myfootdr.com.au/our-clinics/orange-podiatry-centre/
# Processing clinic 24/97: https://www.myfootdr.com.au/our-clinics/north-lakes-podiatry-centre/
# Processing clinic 25/97: https://www.myfootdr.com.au/our-clinics/red-hill-podiatry-centre-allsports/
# Processing clinic 26/97: https://www.myfootdr.com.au/our-clinics/shailer-park-podiatry-centre/
# Processing clinic 27/97: https://www.myfootdr.com.au/our-clinics/hope-island-podiatry-centre/
# Processing clinic 28/97: https://www.myfootdr.com.au/our-clinics/robina-physiologic-podiatry-centre/
# Processing clinic 29/97: https://www.myfootdr.com.au/our-clinics/blacktown-podiatry-centre/
# Processing clinic 30/97: https://www.myfootdr.com.au/our-clinics/palmerston-podiatry-centre/
# Processing clinic 31/97: https://www.myfootdr.com.au/our-clinics/bim-podiatry-woodville/
# Processing clinic 32/97: https://www.myfootdr.com.au/our-clinics/back-in-motion-podiatry-melton/
# Processing clinic 33/97: https://www.myfootdr.com.au/our-clinics/pakenham-podiatry-centre/
# Processing clinic 34/97: https://www.myfootdr.com.au/our-clinics/wantirna-podiatry-centre/
# Processing clinic 35/97: https://www.myfootdr.com.au/our-clinics/hervey-bay-advanced-foot-care-podiatry-centre/
# Processing clinic 36/97: https://www.myfootdr.com.au/our-clinics/traralgon-the-foot-and-ankle-clinic-podiatry-clinic/
# Processing clinic 37/97: https://www.myfootdr.com.au/our-clinics/wavell-heights-podiatry-centre-allsports/
# Processing clinic 38/97: https://www.myfootdr.com.au/our-clinics/aldinga-podiatry-centre/
# Processing clinic 39/97: https://www.myfootdr.com.au/our-clinics/bargara-advanced-foot-care-podiatry-clinic/
# Processing clinic 40/97: https://www.myfootdr.com.au/our-clinics/como-back-in-motion-podiatry/
# Processing clinic 41/97: https://www.myfootdr.com.au/our-clinics/cessnock-back-in-motion-podiatry/
# Processing clinic 42/97: https://www.myfootdr.com.au/our-clinics/bayswater-back-in-motion-podiatry/
# Processing clinic 43/97: https://www.myfootdr.com.au/our-clinics/ipswich-podiatry-centre/
# Processing clinic 44/97: https://www.myfootdr.com.au/our-clinics/dubbo-podiatry-centre/
# Processing clinic 45/97: https://www.myfootdr.com.au/our-clinics/brookwater-podiatry-centre/
# Processing clinic 46/97: https://www.myfootdr.com.au/our-clinics/bundaberg-advanced-foot-care-podiatry-centre/
# Processing clinic 47/97: https://www.myfootdr.com.au/our-clinics/cowboys-centre-of-excellence-nq-foot-ankle-centre/
# Processing clinic 48/97: https://www.myfootdr.com.au/our-clinics/wellington-point-podiatry-centre-allsports/
# Processing clinic 49/97: https://www.myfootdr.com.au/our-clinics/red-hill/
# Processing clinic 50/97: https://www.myfootdr.com.au/our-clinics/beerwah-podiatry-clinic/
# Processing clinic 51/97: https://www.myfootdr.com.au/our-clinics/monto-advanced-foot-care-podiatry-clinic/
# Processing clinic 52/97: https://www.myfootdr.com.au/our-clinics/east-bentleigh-the-foot-and-ankle-clinic-podiatry-clinic/
# Processing clinic 53/97: https://www.myfootdr.com.au/our-clinics/south-hobart-ispahan-podiatry-centre/
# Processing clinic 54/97: https://www.myfootdr.com.au/our-clinics/narellan-podiatry-centre/
# Processing clinic 55/97: https://www.myfootdr.com.au/our-clinics/stafford-podiatry-centre/
# Processing clinic 56/97: https://www.myfootdr.com.au/our-clinics/albany-creek-allsports-podiatry/
# Processing clinic 57/97: https://www.myfootdr.com.au/our-clinics/rockhampton-podiatry-centre/
# Processing clinic 58/97: https://www.myfootdr.com.au/our-clinics/robina-podiatry-centre/
# Processing clinic 59/97: https://www.myfootdr.com.au/our-clinics/brisbane-cbd-podiatry-centre/
# Processing clinic 60/97: https://www.myfootdr.com.au/our-clinics/semaphore-podiatry-clinic/
# Processing clinic 61/97: https://www.myfootdr.com.au/our-clinics/blackwood-podiatry-centre/
# Processing clinic 62/97: https://www.myfootdr.com.au/our-clinics/mackay-podiatry-centre/
# Processing clinic 63/97: https://www.myfootdr.com.au/our-clinics/hawthorne-podiatry-clinic-allsports-podiatry/
# Processing clinic 64/97: https://www.myfootdr.com.au/our-clinics/currambine-podiatry-centre/
# Processing clinic 65/97: https://www.myfootdr.com.au/our-clinics/toowong-podiatry-centre-allsports/
# Processing clinic 66/97: https://www.myfootdr.com.au/our-clinics/allsports-podiatry-parkwood/
# Processing clinic 67/97: https://www.myfootdr.com.au/our-clinics/warragul-podiatry-centre/
# Processing clinic 68/97: https://www.myfootdr.com.au/our-clinics/camp-hill-podiatry-centre/
# Processing clinic 69/97: https://www.myfootdr.com.au/our-clinics/mitchelton-podiatry-centre/
# Processing clinic 70/97: https://www.myfootdr.com.au/our-clinics/gladstone-podiatry-centre/
# Processing clinic 71/97: https://www.myfootdr.com.au/our-clinics/burleigh-waters-back-in-motion-podiatry/
# Processing clinic 72/97: https://www.myfootdr.com.au/our-clinics/yeppoon-podiatry-centre/
# Processing clinic 73/97: https://www.myfootdr.com.au/our-clinics/warwick-podiatry-centre/
# Processing clinic 74/97: https://www.myfootdr.com.au/our-clinics/mountgravatt-podiatry-orthotics-customfootwear/
# Processing clinic 75/97: https://www.myfootdr.com.au/our-clinics/mittagong-podiatry-centre/
# Processing clinic 76/97: https://www.myfootdr.com.au/our-clinics/calamvale-podiatry-centre-allsports/
# Processing clinic 77/97: https://www.myfootdr.com.au/our-clinics/boronia-podiatry-centre/
# Processing clinic 78/97: https://www.myfootdr.com.au/our-clinics/devonport-podiatry-centre/
# Processing clinic 79/97: https://www.myfootdr.com.au/our-clinics/pimpama-allsports-podiatry/
# Processing clinic 80/97: https://www.myfootdr.com.au/our-clinics/chadstone-the-foot-and-ankle-clinic-podiatry-clinic/
# Processing clinic 81/97: https://www.myfootdr.com.au/our-clinics/thuringowa-podiatry-centre/
# Processing clinic 82/97: https://www.myfootdr.com.au/our-clinics/cairns-podiatry-centre/
# Processing clinic 83/97: https://www.myfootdr.com.au/our-clinics/camp-hill-podiatry-centre-allsports/
# Processing clinic 84/97: https://www.myfootdr.com.au/our-clinics/toowoomba-podiatry-centre/
# Processing clinic 85/97: https://www.myfootdr.com.au/our-clinics/ballarat-podiatry-centre/
# Processing clinic 86/97: https://www.myfootdr.com.au/our-clinics/hove-podiatry-centre/
# Processing clinic 87/97: https://www.myfootdr.com.au/our-clinics/noosa/
# Processing clinic 88/97: https://www.myfootdr.com.au/our-clinics/redcliffe-podiatry-centre/
# Processing clinic 89/97: https://www.myfootdr.com.au/our-clinics/unley-podiatry-centre/
# Processing clinic 90/97: https://www.myfootdr.com.au/our-clinics/gumdale-podiatry-centre/
# Processing clinic 91/97: https://www.myfootdr.com.au/our-clinics/tweed-heads-podiatry-centre/
# Processing clinic 92/97: https://www.myfootdr.com.au/our-clinics/newstead-podiatry-clinic-anytime-physio-podiatry/
# Processing clinic 93/97: https://www.myfootdr.com.au/our-clinics/cranbourne-podiatry-centre/
# Processing clinic 94/97: https://www.myfootdr.com.au/our-clinics/my-footdr-nq-foot/
# Processing clinic 95/97: https://www.myfootdr.com.au/our-clinics/forest-lake-podiatry-centre-allsports/
# Processing clinic 96/97: https://www.myfootdr.com.au/our-clinics/bathurst-podiatry-centre/
# Processing clinic 97/97: https://www.myfootdr.com.au/our-clinics/fortitude-valley-podiatry-centre/
